# %% [markdown]
# Рыков Михаил 4 курс группа КМА 3 лаба(Липецк)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy.integrate import odeint
url = 'https://raw.githubusercontent.com/Ryk0vMikhail/vsulab/main/lipetsk1.csv'
df = pd.read_csv(url)
print(df)
Years = np.array(df['Years'])
Population = np.array(df['Population'])
def dydt(Years,Population):
  k = 0.0056
  return k*Years

plt.plot(Years, Population)
plt.grid(True)
# Out:
#     Years  Population
# 0    2003      504400
# 1    2005      502800
# 2    2009      502535
# 3    2010      502015
# 4    2012      508066
# 5    2013      509098
# 6    2014      509719
# 7    2015      510152
# 8    2016      510020
# 9    2017      510439
# 10   2018      509735
# 11   2019      509420
# 12   2020      508573
# 13   2021      503216
# 14   2022      496447
